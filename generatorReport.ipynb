# %%
import generatorDetermine as gd

# %%
    print("RAVNOMER")
    print("input a:")
    a = int(input())
    print("input b:")
    b = int(input())
    size = 1000000
    gd.showHist([gd.ravnomer(a, b, gd.getRandom()) for _ in range(0, size)], "ravnomer.png")
# Out:
# RAVNOMER
# input a:
# 4
# input b:
# 45

# %%
    print("GAUSS")
    print("input mat expected:")
    mx = int(input())
    print("input sigma:")
    sx = int(input())
    n = 6
    size = 1000000
    gd.showHist([gd.gauss(mx, sx, [gd.getRandom() for _ in range(0, n)]) for _ in range(0, size)], "gauss.png")
# Out:
# GAUSS
# input mat expected:
# 4
# input sigma:
# 46

# %%
    print("EXPONENTIAL")
    print("input lambda:")
    lam = int(input())
    size = 1000000
    gd.showHist([gd.exponential(lam, gd.getRandom()) for _ in range(0, size)], "exponential.png")
# Out:
# EXPONENTIAL
# input lambda:
# 3

# %%
    print("GAMMA")
    print("input lambda:")
    lam = int(input())
    print("input nu:")
    nu = int(input())
    n = 6
    size = 1000000
    gd.showHist([gd.gamma(lam, nu, [gd.getRandom() for _ in range(0, n)]) for _ in range(0, size)], "gamma.png")
# Out:
# GAMMA
# input lambda:
# 4
# input nu:
# 6

# %%
    print("TRIANGLE MAX")
    print("input a:")
    a = int(input())
    print("input b:")
    b = int(input())
    size = 1000000
    gd.showHist([gd.triangleMax(a, b, gd.getRandom(), gd.getRandom()) for _ in range(0, size)], "triangleMax.png")
# Out:
# TRIANGLE MAX
# input a:
# 6
# input b:
# 5

# %%
    print("TRIANGLE MIN")
    print("input a:")
    a = int(input())
    print("input b:")
    b = int(input())
    size = 1000000
    gd.showHist([gd.triangleMin(a, b, gd.getRandom(), gd.getRandom()) for _ in range(0, size)], "triangleMin.png")
# Out:
# TRIANGLE MIN
# input a:
# 78
# input b:
# 199

# %%
    print("SIMPSON")
    print("input a:")
    a = int(input())
    print("input b:")
    b = int(input())
    size = 1000000
    gd.showHist([gd.simpson(a, b, gd.getRandom(), gd.getRandom()) for _ in range(0, size)], "simpson.png")
# Out:
# SIMPSON
# input a:
# 9
# input b:
# 198
